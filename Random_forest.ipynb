# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import classification_report, accuracy_score
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import GridSearchCV

# %%
df = pd.read_csv("ClassicHit.csv")

# %%
df = pd.read_csv("ClassicHit.csv")

# %%
label_encoder = LabelEncoder()
df['Genre'] = label_encoder.fit_transform(df['Genre'])

# %%
column_to_drop=["Genre","Artist","Track"]
X = df.drop(column_to_drop, axis=1)  # Features
y = df["Genre"]               # Target variable
feature_names = X.columns.tolist()
y
# Out:
# 0        Alt. Rock
# 1        Alt. Rock
# 2        Alt. Rock
# 3        Alt. Rock
# 4        Alt. Rock
#            ...
# 21584        World
# 21585        World
# 21586        World
# 21587        World
# 21588        World
# Name: Genre, Length: 21589, dtype: object

# %%
categorical_cols = X.select_dtypes(include=['object']).columns
print(f"Categorical columns found: {categorical_cols}")
# Out:
# Categorical columns found: Index([], dtype='object')

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42, class_weight='balanced')

# %%
model = RandomForestClassifier(n_estimators=100, random_state=42)
model.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [None, 20],
    'min_samples_split': [5, 10],
    'max_features': ['sqrt', 'log2']
}

grid_search = GridSearchCV(RandomForestClassifier(random_state=42), param_grid, cv=5)
grid_search.fit(X_train, y_train)
best_model = grid_search.best_estimator_

# %%
best_model = grid_search.best_estimator_ # Optimized model
print("Best Parameters:", best_model)
# Out:
# Best Parameters: RandomForestClassifier(min_samples_split=10, n_estimators=200, random_state=42)

# %%
best_params = grid_search.best_params_  # Best parameter combination
best_model = grid_search.best_estimator_ # Optimized model
print("Best Parameters:", best_params)
# Out:
# Best Parameters: {'max_depth': None, 'max_features': 'sqrt', 'min_samples_split': 10, 'n_estimators': 200}

# %%
y_pred = best_model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.5467546754675467
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.50      0.21      0.30       243
#            1       0.59      0.32      0.41       190
#            2       0.47      0.30      0.37       241
#            3       0.54      0.52      0.53       200
#            4       0.68      0.73      0.70       219
#            5       0.48      0.31      0.38       189
#            6       0.13      0.05      0.07       110
#            7       0.69      0.37      0.48       102
#            8       0.65      0.77      0.70       224
#            9       0.57      0.65      0.61       269
#           10       0.52      0.86      0.65      1116
#           11       0.62      0.64      0.63       249
#           12       0.35      0.11      0.16       242
#           13       0.65      0.65      0.65       225
#           14       0.51      0.35      0.42       126
# ...

# %%
final_model = RandomForestClassifier(**best_params, random_state=42)
final_model.fit(X, y)

y_pred = final_model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9161716171617161
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.95      0.81      0.88       243
#            1       0.98      0.93      0.96       190
#            2       0.97      0.88      0.92       241
#            3       0.91      0.91      0.91       200
#            4       0.95      0.98      0.96       219
#            5       0.96      0.85      0.90       189
#            6       0.92      0.73      0.81       110
#            7       0.98      0.91      0.94       102
#            8       0.95      0.96      0.95       224
#            9       0.90      0.96      0.93       269
#           10       0.84      0.99      0.91      1116
#           11       0.95      0.94      0.94       249
#           12       0.95      0.71      0.81       242
#           13       0.93      0.97      0.95       225
#           14       0.96      0.90      0.93       126
# ...

# %%
final_model = RandomForestClassifier(**best_model, random_state=42)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[201], line 1
# ----> 1 final_model = RandomForestClassifier(**best_model, random_state=42)
#
# TypeError: sklearn.ensemble._forest.RandomForestClassifier() argument after ** must be a mapping, not RandomForestClassifier

# %%
y_pred = model.predict(X_test)
print("Accuracy:", accuracy_score(y_test, y_pred))
print("Classification Report:\n", classification_report(y_test, y_pred))

# %%
column_to_drop=["Genre","Artist","Track","Year","Duration"]
X = df.drop(column_to_drop, axis=1)  # Features

# %%
df_processed = pd.concat([X, y], axis=1)
df_processed.to_csv('Pre_music_genre.csv', index=False)

# %%
# Check for non-numeric columns
non_numeric_cols = X.select_dtypes(include=['object']).columns
print(f"Non-numeric columns: {non_numeric_cols}")

X["Tempo"].unique()
